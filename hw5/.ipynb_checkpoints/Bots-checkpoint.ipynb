# %%
# Zachary Clark

# %%
#step 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
#step 2
df = pd.read_csv('clean_data.csv', delimiter = ',')

print('Number of elements: ', df.shape[0])
df.head()
# Out:
# Number of elements:  2672
#              id       screen_name                   location  \
# 0  8.160000e+17  "HoustonPokeMap"              "Houston, TX"
# 1  4.843621e+09         kernyeahx  Templeville town, MD, USA
# 2  4.303727e+09   mattlieberisbot                        NaN
# 3  3.063139e+09         sc_papers                        NaN
# 4  2.955142e+09      lucarivera16      Dublin, United States
#
#                                          description  \
# 0  "Rare and strong PokŽmon in Houston, TX. See m...
# 1  From late 2014 Socium Marketplace will make sh...
# 2  Inspired by the smart, funny folks at @replyal...
# 3                                                NaN
# 4             Inspiring cooks everywhere since 1956.
#
#                          url  followers_count  friends_count  listed_count  \
# 0  "https://t.co/dnWuDbFRkt"             1291              0            10
# 1                        NaN                1            349             0
# 2    https://t.co/P1e1o0m4KC             1086              0            14
# 3                        NaN               33              0             8
# 4                        NaN               11            745             0
#
#                          created_at  favourites_count  verified  \
# 0  "Mon Jan 02 02:25:26 +0000 2017"                 0     False
# 1                     2/1/2016 7:37                38     False
# 2    Fri Nov 20 18:53:22 +0000 2015                 0     False
# 3                   2/25/2015 20:11                 0     False
# 4                    1/1/2015 17:44               146     False
#
#    statuses_count  lang                                             status  \
# 0           78554  "en"  {\n      "created_at": "Sun Mar 12 15:44:04 +0...
# 1              31    en                                                NaN
# 2             713    en  {'retweeted': False, 'is_quote_status': False,...
# 3             676    en  Construction of human anti-tetanus single-chai...
# 4             185    en                                                NaN
#
#    default_profile  default_profile_image                  name  bot
# 0             True                  False  "Houston PokŽ Alert"    1
# 1             True                  False           Keri Nelson    1
# 2             True                  False    Matt Lieber Is Bot    1
# 3             True                   True    single cell papers    1
# 4            False                  False          lucarivera16    1

# %%
#step 3
missing_values = df.isna()
missing_counts = missing_values.sum()
print(missing_counts)

#drop location and url columns
df.drop('location', axis=1, inplace=True)
df.drop('url', axis=1, inplace=True)

df.head()
# Out:
# id                          0
# screen_name                 0
# location                  963
# description               387
# url                      1347
# followers_count             0
# friends_count               0
# listed_count                0
# created_at                  0
# favourites_count            0
# verified                    0
# statuses_count              0
# lang                        0
# status                    325
# default_profile             0
# default_profile_image       0
# name                        0
# bot                         0
# dtype: int64
#              id       screen_name  \
# 0  8.160000e+17  "HoustonPokeMap"
# 1  4.843621e+09         kernyeahx
# 2  4.303727e+09   mattlieberisbot
# 3  3.063139e+09         sc_papers
# 4  2.955142e+09      lucarivera16
#
#                                          description  followers_count  \
# 0  "Rare and strong PokŽmon in Houston, TX. See m...             1291
# 1  From late 2014 Socium Marketplace will make sh...                1
# 2  Inspired by the smart, funny folks at @replyal...             1086
# 3                                                NaN               33
# 4             Inspiring cooks everywhere since 1956.               11
#
#    friends_count  listed_count                        created_at  \
# 0              0            10  "Mon Jan 02 02:25:26 +0000 2017"
# 1            349             0                     2/1/2016 7:37
# 2              0            14    Fri Nov 20 18:53:22 +0000 2015
# 3              0             8                   2/25/2015 20:11
# 4            745             0                    1/1/2015 17:44
#
#    favourites_count  verified  statuses_count  lang  \
# 0                 0     False           78554  "en"
# 1                38     False              31    en
# 2                 0     False             713    en
# 3                 0     False             676    en
# 4               146     False             185    en
#
#                                               status  default_profile  \
# 0  {\n      "created_at": "Sun Mar 12 15:44:04 +0...             True
# 1                                                NaN             True
# 2  {'retweeted': False, 'is_quote_status': False,...             True
# 3  Construction of human anti-tetanus single-chai...             True
# 4                                                NaN            False
#
#    default_profile_image                  name  bot
# 0                  False  "Houston PokŽ Alert"    1
# 1                  False           Keri Nelson    1
# 2                  False    Matt Lieber Is Bot    1
# 3                   True    single cell papers    1
# 4                  False          lucarivera16    1

# %%
#step 4
df_bot = df[df.bot == 1]

#plot bots
x = np.array(df_bot['friends_count'])
y = np.array(df_bot['followers_count'])

plt.scatter(x,y,label='bot',s=5)

df_not_bot = df[df.bot == 0]

#plot not bots
x = np.array(df_not_bot['friends_count'])
y = np.array(df_not_bot['followers_count'])

plt.scatter(x,y,label='not bot',s=5)

#label x and y axis
plt.xlabel('friend count')
plt.ylabel('follower count')

#limit x and y axis
plt.xlim(0, 6000)
plt.ylim(0, 10000)

#show plot and legend
plt.legend()
plt.show()

# %%
#step 5

Bag_of_words = ['bot', 'follow me', 'free', 'fake', 'virus', 'troll', 'clone', 'tweet me']


#detect any of above strings in column of df and create new column
df['screen_name_binary'] = [any(word.lower() in screen_name.lower() for word in Bag_of_words) for screen_name in df['screen_name']]
df['name_binary'] = [any(word.lower() in name.lower() for word in Bag_of_words) for name in df['name']]
df['description_binary'] = [any(word.lower() in str(description) for word in Bag_of_words) for description in df['description']]
df['status_binary'] = [any(word.lower() in str(status) for word in Bag_of_words) for status in df['status']]

df.head()
# Out:
#              id       screen_name  \
# 0  8.160000e+17  "HoustonPokeMap"
# 1  4.843621e+09         kernyeahx
# 2  4.303727e+09   mattlieberisbot
# 3  3.063139e+09         sc_papers
# 4  2.955142e+09      lucarivera16
#
#                                          description  followers_count  \
# 0  "Rare and strong PokŽmon in Houston, TX. See m...             1291
# 1  From late 2014 Socium Marketplace will make sh...                1
# 2  Inspired by the smart, funny folks at @replyal...             1086
# 3                                                NaN               33
# 4             Inspiring cooks everywhere since 1956.               11
#
#    friends_count  listed_count                        created_at  \
# 0              0            10  "Mon Jan 02 02:25:26 +0000 2017"
# 1            349             0                     2/1/2016 7:37
# 2              0            14    Fri Nov 20 18:53:22 +0000 2015
# 3              0             8                   2/25/2015 20:11
# 4            745             0                    1/1/2015 17:44
#
#    favourites_count  verified  statuses_count  lang  \
# 0                 0     False           78554  "en"
# 1                38     False              31    en
# 2                 0     False             713    en
# 3                 0     False             676    en
# 4               146     False             185    en
#
#                                               status  default_profile  \
# 0  {\n      "created_at": "Sun Mar 12 15:44:04 +0...             True
# 1                                                NaN             True
# 2  {'retweeted': False, 'is_quote_status': False,...             True
# 3  Construction of human anti-tetanus single-chai...             True
# 4                                                NaN            False
#
#    default_profile_image                  name  bot  screen_name_binary  \
# 0                  False  "Houston PokŽ Alert"    1               False
# 1                  False           Keri Nelson    1               False
# 2                  False    Matt Lieber Is Bot    1                True
# 3                   True    single cell papers    1               False
# 4                  False          lucarivera16    1               False
#
#    name_binary  description_binary  status_binary
# 0        False               False          False
# 1        False               False          False
# 2         True                True           True
# 3        False               False          False
# 4        False               False          False

# %%
#step 6

#create attribute set
subset = ['friends_count', 'followers_count', 'screen_name_binary', 'name_binary', 'status_binary', 'verified', 'statuses_count']
X = df[subset]
y = df.bot

#split into 70% training and 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
clf = DecisionTreeClassifier(criterion='entropy')

#percent are bots
print(y_train.sum()/y_train.shape[0])
print(y_test.sum()/y_test.shape[0])

#learn from data
clf.fit(X_train, y_train)
train_pred = clf.predict(X_train)
test_pred = clf.predict(X_test)

print('accuracy of training: ', accuracy_score(y_train, train_pred))
print('accuracy of test:' , accuracy_score(y_test, test_pred))
# Out:
# 0.4588235294117647
# 0.4713216957605985
# accuracy of training:  0.9994652406417113
# accuracy of test: 0.8391521197007481

# %%
# 1) Based on the plot in step 4 part 1, can you determine if friends_count and followers_count can be used for classification? 
# Is there a pattern? 
# Consider zooming in on the plot to get a better picture.

# I think it would be difficult to use friends_count and followers_count on their own for classification. 
# There doesn't seem to be a discernible pattern to the bots and humans.

# 2) What was the training accuracy? What was the testing accuracy? Based on this
# can you conclude that the decision tree is a good Machine Learning model for
# your dataset?

# Training accuracy was 0.9994652406417113
# Testing accuracy was 0.8416458852867831
# Yes, the decision tree seems like a good model for the data set.

# 3) What percentage of the training and test data are bots? If you had a different
# dataset where only 10% of the rows were bots, would 85% accuracy be good?

# 0.4588235294117647 of the training set are bots
# 0.4713216957605985 of the testing set are bots
# If only 10% of the rows were bots I think 85% accuracy would still be good.


# 4) When you split the data into train and test in Step 6, you might have assigned the
# first 70% of the data to the training data and the last 30% of the data as test data.
# Can you see any problems with doing this? Can you think of any better
# alternatives?

# The problem with splitting the first 70% to training is that the bots may be front loaded or back loaded in the dataset.
# It could result in the testing set containing 100% bots and the training set containing no bots
# The solution is to randomely assign elements to the training and testing set.

# 5) The Decision Tree Classifier learned this data set quite effectively. Can you give
# an example of a classification task for which decision tree would perform poorly?

# The Decision Tree Classifier could perform poorly when dealing with high dimensional data. 
# An example of this would be image classification where each image has many features.

# 6) Often in data science you are just given a data set and a task (e.g., learn a
# classifier for detecting bots). The instructions in the assignment made a lot of
# decisions for you. List 5 examples of these decisions that the assignment made
# for you. (In other words, if you were trying to solve this problem without this
# homework guiding you, what would you have to decide yourself in processing
# your data and designing your classifier?)


# 1. Deleting columns with more than 35% missing values
# 2. Plotting bots vs. non bots
# 3. Creating new dimensions that were true when certain keywords were detected
# 4. Choosing which attributes to use when creating training and testing sets
# 4. Choosing percentage of data to be training and testing
